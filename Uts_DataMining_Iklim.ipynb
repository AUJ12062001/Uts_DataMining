# %% [markdown]
# <a href="https://colab.research.google.com/github/AUJ12062001/Uts_DataMining/blob/main/Uts_DataMining_Iklim.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas-profiling
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import ydata_profiling
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a2646f3a-7164-4a92-a767-ec7609b3be50" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a2646f3a-7164-4a92-a767-ec7609b3be50">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
input_file = '/content/DatasetCuaca_convert.xlsx'
df = pd.read_excel(input_file)
pilih_kolom1 = ['Suhu Udara','Tekanan Udara','Kelembapan Udara','Kecepatan Angin','Curah Hujan']
pilih_kolom2 = range(1, 6)
output_file = '/content/HasilKonvertDataCuaca.csv'
suhu_udara =['Suhu Udara']
curah_hujan =['Curah Hujan']
kelembapan_udara =['Kelembapan Udara']

# %%
def keseluruhan_data(input_file):
  display(df)
def tampilkan_pilihan(input_file, pilih_kolom1):
  selected_data = df[pilih_kolom1]
  display(selected_data)
def kecsv(input_file, output_file, pilih_kolom2):
  selected_data = df.iloc[:, pilih_kolom2]
  selected_data.to_csv(output_file, index=False)
def tampilkan_csv(output_file):
    fcsv = pd.read_csv(output_file)
    display(fcsv)


def mean_median_modus_suhu_udara(output_file, suhu_udara):
    kolom = df[suhu_udara]
    mean = kolom.mean()
    median = kolom.median()
    mode = kolom.mode().values[0]
    display(kolom)
    print("\n Keluaran Nilai Mean, Median, Dan Modus Dari Suhu Udara :\n")
    print("Mean:", float(mean))
    print("Median:", float(median))
    print("Modus:", float(mode))


def mean_median_modus_curah_hujan(output_file, curah_hujan):
    kolom2 = df[curah_hujan]
    mean = kolom2.mean()
    median = kolom2.median()
    mode = kolom2.mode().values[0]
    display(kolom2)
    print("\n Keluaran Nilai Mean, Median, Dan Modus Dari Curah Hujan :\n")
    print("Mean:", float(mean))
    print("Median:", float(median))
    print("Modus:", float(mode))

def create_boxplot(output_file, x_column, y_column):
    df = pd.read_csv(output_file)
    plt.figure(figsize=(12, 5))
    x_column = 'Kelembapan Udara'
    y_column = 'Curah Hujan'
    sns.boxplot(x='Kelembapan Udara', y='Curah Hujan', data=df[[x_column, y_column]])
    plt.title('Boxplot Kelembapan Udara dan Curah Hujan')
    plt.xlabel('Kelembapan Udara')
    plt.ylabel('Curah Hujan')
    plt.show()

def Buat_Scatterplot(output_file, kelembapan_udara, curah_hujan):
    fcsv = pd.read_csv(output_file)
    x_data = fcsv[kelembapan_udara]
    y_data = fcsv[curah_hujan]      
    plt.figure(figsize=(12, 5))
    sns.regplot(x=x_data, y=y_data)
    plt.xlabel(kelembapan_udara)
    plt.ylabel(curah_hujan)
    plt.title("Scatter Plot Dari : {} dan {}".format(kelembapan_udara, curah_hujan))
    plt.show()

# %%
keseluruhan_data(input_file)
# Out:
#    Bulan dan Tahun  Suhu Udara  Tekanan Udara  Kelembapan Udara  \
# 0       2019-01-01        27.9         1009.0              83.1
# 1       2019-02-01        27.6         1011.0              81.6
# 2       2019-03-01        27.8         1009.6              81.5
# 3       2019-04-01        27.9         1008.9              85.1
# 4       2019-05-01        27.8         1009.5              83.9
# 5       2019-06-01        26.7         1009.5              89.6
# 6       2019-07-01        25.6         1010.2              89.7
# 7       2019-08-01        25.9         1010.5              85.9
# 8       2019-09-01        26.2         1011.4              84.8
# 9       2019-10-01        26.8         1009.4              88.0
# 10      2019-11-01        28.0         1008.6              82.7
# 11      2019-12-01        28.0         1008.5              81.7
# 12      2020-01-01        28.3         1009.0              79.0
# 13      2020-02-01        28.4         1009.7              78.0
# ...

# %%
tampilkan_pilihan(input_file, pilih_kolom1)
# Out:
#     Suhu Udara  Tekanan Udara  Kelembapan Udara  Kecepatan Angin  Curah Hujan
# 0         27.9         1009.0              83.1              4.5         97.1
# 1         27.6         1011.0              81.6              5.0        134.7
# 2         27.8         1009.6              81.5              4.6        118.1
# 3         27.9         1008.9              85.1              4.2        333.9
# 4         27.8         1009.5              83.9              4.1        193.7
# 5         26.7         1009.5              89.6              4.9        362.0
# 6         25.6         1010.2              89.7              5.2        298.0
# 7         25.9         1010.5              85.9              6.2        141.0
# 8         26.2         1011.4              84.8              6.5         76.7
# 9         26.8         1009.4              88.0              4.5        360.0
# 10        28.0         1008.6              82.7              4.7         25.9
# ...

# %%
kecsv(input_file, output_file, pilih_kolom2)
print("File hasil konversi dapat ditemukan di lokasi:", output_file)
# Out:
# File hasil konversi dapat ditemukan di lokasi: /content/HasilKonvertDataCuaca.csv

# %%
tampilkan_csv(output_file)
# Out:
#     Suhu Udara  Tekanan Udara  Kelembapan Udara  Kecepatan Angin  Curah Hujan
# 0         27.9         1009.0              83.1              4.5         97.1
# 1         27.6         1011.0              81.6              5.0        134.7
# 2         27.8         1009.6              81.5              4.6        118.1
# 3         27.9         1008.9              85.1              4.2        333.9
# 4         27.8         1009.5              83.9              4.1        193.7
# 5         26.7         1009.5              89.6              4.9        362.0
# 6         25.6         1010.2              89.7              5.2        298.0
# 7         25.9         1010.5              85.9              6.2        141.0
# 8         26.2         1011.4              84.8              6.5         76.7
# 9         26.8         1009.4              88.0              4.5        360.0
# 10        28.0         1008.6              82.7              4.7         25.9
# ...

# %%
mean_median_modus_suhu_udara(output_file, suhu_udara)
# Out:
#     Suhu Udara
# 0         27.9
# 1         27.6
# 2         27.8
# 3         27.9
# 4         27.8
# 5         26.7
# 6         25.6
# 7         25.9
# 8         26.2
# 9         26.8
# 10        28.0
# 11        28.0
# 12        28.3
# 13        28.4
# 14        27.2
# 15        27.8
# 16        28.0
# 17        26.8
# 18        26.4
# 19        26.4
# 20        26.6
# 21        27.0
# 22        27.2
# 23        27.4
# 24        27.4
# 25        27.3
# 26        27.1
# 27        27.4
# 28        27.2
# 29        26.7
# 30        26.6
# 31        26.6
# 32        26.5
# 33        27.5
# 34        26.9
# 35        26.9
#  Keluaran Nilai Mean, Median, Dan Modus Dari Suhu Udara :
#
# Mean: 27.16111111111111
# Median: 27.2
# Modus: 26.6

# %%
mean_median_modus_curah_hujan(output_file, curah_hujan)
# Out:
#     Curah Hujan
# 0          97.1
# 1         134.7
# 2         118.1
# 3         333.9
# 4         193.7
# 5         362.0
# 6         298.0
# 7         141.0
# 8          76.7
# 9         360.0
# 10         25.9
# 11         81.7
# 12         35.6
# 13         38.7
# 14        165.8
# 15        223.5
# 16        243.2
# 17        516.7
# 18        747.6
# 19        391.5
# 20        678.2
# 21        394.4
# 22        283.1
# 23        147.0
# 24        377.0
# 25        175.0
# 26        236.0
# 27        121.0
# 28        233.0
# 29        478.0
# 30        302.0
# 31        511.0
# 32        519.0
# 33        180.0
# 34        287.0
# 35        330.0
#  Keluaran Nilai Mean, Median, Dan Modus Dari Curah Hujan :
#
# Mean: 273.2527777777778
# Median: 239.6
# Modus: 25.9

# %%
x_column = 'Kelembapan Udara'
y_column = 'Curah Hujan'
Buat_Scatterplot(output_file, x_column, curah_hujan)

# %%
create_boxplot(output_file, x_column, y_column)

# %%
def Deviasi_Curah_Hujan(csv_file, column):
    df = pd.read_csv(csv_file)
    data = df[column]
    std_dev = data.std()
    plt.figure(figsize=(8, 6))
    plt.hist(data, bins=10, alpha=0.5, color='green', edgecolor='black', label=column)
    plt.axvline(x=std_dev, color='Red', linestyle='--', linewidth=2, label='Standard Deviation')
    plt.title('Histogram Dari: {}'.format(column))
    plt.xlabel('Value')
    plt.ylabel('Frequency')
    plt.legend()
    plt.show()

def Deviasi_Suhu_Udara(csv_file, column2):
    df = pd.read_csv(csv_file)
    data = df[column2]
    std_dev = data.std()
    plt.figure(figsize=(8, 6))
    plt.hist(data, bins=10, alpha=0.5, color='yellow', edgecolor='black', label=column2)
    plt.axvline(x=std_dev, color='red', linestyle='--', linewidth=2, label='Standard Deviation')
    plt.title('Histogram Dari: {}'.format(column2))
    plt.xlabel('Value')
    plt.ylabel('Frequency')
    plt.legend()
    plt.show()    

csv_file = output_file
column = 'Curah Hujan'
column2 = 'Suhu Udara'

Deviasi_Curah_Hujan(csv_file, column)
Deviasi_Suhu_Udara(csv_file, column2)

# %%
# Membaca dataset
data = pd.read_csv('/content/HasilKonvertDataCuaca.csv')

# Menampilkan informasi umum tentang dataset
data_info = data.describe(include='all').transpose()

# Menghitung jumlah missing value pada setiap kolom
missing_values = data.isnull().sum()

# Menghitung korelasi antar kolom
correlation = data.corr()

# Menampilkan statistik kuantitatif untuk kolom numerik
numeric_stats = data.select_dtypes(include=['float64', 'int64']).describe().transpose()

# Menampilkan mode untuk kolom kategorikal
categorical_mode = data.select_dtypes(include=['object']).mode().transpose()

# Mengidentifikasi outlier menggunakan metode IQR
Q1 = data.quantile(0.25)
Q3 = data.quantile(0.75)
IQR = Q3 - Q1
outliers = ((data < (Q1 - 1.5 * IQR)) | (data > (Q3 + 1.5 * IQR))).sum()

# Menyusun laporan non-grafis
report = pd.concat([data_info, missing_values.rename('Missing Values'), numeric_stats, categorical_mode.rename(columns={0: 'Mode'}), outliers.rename('Outliers')], axis=1)

# Menampilkan laporan non-grafis
print(report)
# Out:
#                   count         mean         std     min       25%      50%  \
# Suhu Udara         36.0    27.161111    0.678350    25.6    26.675    27.20
# Tekanan Udara      36.0  1009.052778    0.959907  1007.2  1008.475  1009.00
# Kelembapan Udara   36.0    85.294444    3.106670    78.0    83.700    85.05
# Kecepatan Angin    36.0     4.350000    0.618061     3.7     4.000     4.15
# Curah Hujan        36.0   273.252778  176.640231    25.9   139.425   239.60
#
#                        75%     max  Missing Values  count         mean  \
# Suhu Udara          27.800    28.4               0   36.0    27.161111
# Tekanan Udara     1009.525  1011.4               0   36.0  1009.052778
# Kelembapan Udara    88.000    90.0               0   36.0    85.294444
# Kecepatan Angin      4.525     6.5               0   36.0     4.350000
# Curah Hujan        365.750   747.6               0   36.0   273.252778
#
#                          std     min       25%      50%       75%     max  \
# ...
